# %%
dados = ("Nome", "João")
coordenadas = (10.5, 20.3)
print(coordenadas[1])
x, y = coordenadas
tuplas_concatenadas = dados + coordenadas
print(tuplas_concatenadas)
dados_pessoais = {
    "nome": "João",
    "idade": 25,
    "cidade": "Belo Horizonte"
}
print(dados_pessoais["nome"])
print(dados_pessoais.get("idade"))
print(dados_pessoais.get("altura", "Não informado"))
dados_pessoais["nome"] = "Vítor"
dados_pessoais["altura"] = 169
matriz = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]
elemento = matriz[1][2]

# Adição de Linha
nova_linha = [10, 11, 12]
matriz.append(nova_linha)

# Adição de Coluna
for linha in matriz:
    linha.append(0)

print("\nParabéns pra você!")
print("Nesta data querida!")
print("Muitas felicidades!")
print("Muitos anos de vida!")
print("\nParabéns pra você!")
print("Nesta data querida!")
print("Muitas felicidades!")
print("Muitos anos de vida!")
print("\nParabéns pra você!")
print("Nesta data querida!")
print("Muitas felicidades!")
print("Muitos anos de vida!")


def parabens():
    print("\nParabéns pra você!")
    print("Nesta data querida!")
    print("Muitas felicidades!")
    print("Muitos anos de vida!")


parabens()
parabens()
parabens()
# Out:
# 20.3
# ('Nome', 'João', 10.5, 20.3)
# João
# 25
# Não informado

# %%
# Out:
# 20.3
